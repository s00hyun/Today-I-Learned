# %%
import tensorflow as tf

# %%
hello = tf.constant("Hello, TensorFlow!")
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)
node3 = tf.add(node1, node2)

# %%
print("node1:", node1, "node2:", node2)
print("node3: ", node3)
# Out:
# node1: Tensor("Const_2:0", shape=(), dtype=float32) node2: Tensor("Const_3:0", shape=(), dtype=float32)
# node3:  Tensor("Add:0", shape=(), dtype=float32)

# %%
sess = tf.Session()
print("sess.run(node1, node2): ", sess.run([node1, node2]))
print("sess.run(node3): ", sess.run(node3))
# Out:
# sess.run(node1, node2):  [3.0, 4.0]
# sess.run(node3):  7.0

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b

print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict={a: [1, 3], b: [2, 4]}))
# Out:
# 7.5
# [3. 7.]

# %%
# 1. Build graph using TF operations

x_train = [1, 2, 3]
y_train = [1, 2, 3]

# [1]: 값이 하나인 1차원 array를 나타내는 shape
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# H(x) = Wx + b
hypothesis = x_train * W + b

# cost/loss function
# t = [1., 2., 3., 4.], tf.reduce_mean(t) ==> 2.5
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
# 2. Run/update graph and get results

# session의 그래프를 launch
sess = tf.Session()
#graph의 global variable을 초기화. W, b를 사용하기 위해 반드시 필요
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.5618965 [0.75267917] [-0.22724354]
# 20 0.0063649584 [1.0138984] [-0.10676627]
# 40 0.0012115126 [1.0370116] [-0.0912938]
# 60 0.0010588883 [1.0375352] [-0.08600784]
# 80 0.00096132373 [1.0359865] [-0.08187099]
# 100 0.0008730858 [1.0343158] [-0.07801425]
# 120 0.0007929479 [1.0327052] [-0.07434701]
# 140 0.00072016806 [1.0311682] [-0.07085293]
# 160 0.0006540685 [1.0297035] [-0.06752307]
# 180 0.000594038 [1.0283076] [-0.0643497]
# 200 0.0005395148 [1.0269772] [-0.06132553]
# 220 0.000489994 [1.0257094] [-0.05844348]
# 240 0.00044501867 [1.0245012] [-0.05569685]
# 260 0.00040417546 [1.0233498] [-0.05307933]
# 280 0.00036707925 [1.0222524] [-0.05058485]
# 300 0.0003333901 [1.0212066] [-0.04820764]
# 320 0.00030279005 [1.0202099] [-0.04594205]
# 340 0.00027499822 [1.01926] [-0.0437828]
# 360 0.00024975286 [1.0183548] [-0.0417251]
# 380 0.00022683037 [1.0174923] [-0.03976412]
# 400 0.00020601065 [1.0166701] [-0.03789531]
# 420 0.00018710126 [1.0158868] [-0.03611434]
# 440 0.00016992853 [1.01514] [-0.0344171]
# 460 0.00015433309 [1.0144286] [-0.03279958]
# 480 0.00014016755 [1.0137506] [-0.03125817]
# 500 0.00012730157 [1.0131042] [-0.02978915]
# 520 0.00011561807 [1.0124885] [-0.02838914]
# 540 0.00010500621 [1.0119015] [-0.02705498]
# 560 9.536799e-05 [1.0113423] [-0.0257835]
# 580 8.66143e-05 [1.0108092] [-0.02457179]
# 600 7.866674e-05 [1.0103014] [-0.02341709]
# 620 7.144649e-05 [1.0098172] [-0.02231665]
# 640 6.488838e-05 [1.0093557] [-0.02126783]
# 660 5.8932987e-05 [1.008916] [-0.02026829]
# 680 5.3523483e-05 [1.008497] [-0.01931575]
# 700 4.861034e-05 [1.0080976] [-0.01840798]
# 720 4.414923e-05 [1.0077171] [-0.01754288]
# 740 4.0097122e-05 [1.0073545] [-0.01671845]
# 760 3.6416615e-05 [1.0070089] [-0.01593277]
# 780 3.3075044e-05 [1.0066795] [-0.01518403]
# 800 3.0038464e-05 [1.0063655] [-0.01447047]
# 820 2.7281561e-05 [1.0060663] [-0.0137904]
# 840 2.4777795e-05 [1.0057813] [-0.01314227]
# 860 2.2503393e-05 [1.0055096] [-0.01252462]
# 880 2.0438316e-05 [1.0052508] [-0.01193604]
# 900 1.8562643e-05 [1.005004] [-0.01137516]
# 920 1.6858734e-05 [1.0047688] [-0.01084062]
# 940 1.5311753e-05 [1.0045447] [-0.01033119]
# 960 1.3906163e-05 [1.0043311] [-0.00984569]
# 980 1.2630164e-05 [1.0041276] [-0.00938297]
# 1000 1.14708355e-05 [1.0039335] [-0.00894205]
# 1020 1.0417738e-05 [1.0037488] [-0.00852178]
# 1040 9.4621855e-06 [1.0035727] [-0.00812135]
# 1060 8.59358e-06 [1.0034047] [-0.00773972]
# 1080 7.804816e-06 [1.0032446] [-0.007376]
# 1100 7.0883375e-06 [1.0030922] [-0.00702937]
# 1120 6.4377177e-06 [1.0029469] [-0.00669902]
# 1140 5.846951e-06 [1.0028085] [-0.0063842]
# 1160 5.310419e-06 [1.0026765] [-0.00608421]
# 1180 4.8229163e-06 [1.0025506] [-0.00579828]
# 1200 4.380458e-06 [1.0024309] [-0.0055258]
# 1220 3.978496e-06 [1.0023167] [-0.00526616]
# 1240 3.6133067e-06 [1.0022078] [-0.00501871]
# 1260 3.2817152e-06 [1.0021039] [-0.00478288]
# 1280 2.9805651e-06 [1.0020051] [-0.00455814]
# 1300 2.7070494e-06 [1.0019109] [-0.00434398]
# 1320 2.458721e-06 [1.0018213] [-0.00413988]
# 1340 2.233148e-06 [1.0017357] [-0.00394539]
# 1360 2.0281439e-06 [1.0016541] [-0.00376003]
# 1380 1.8421433e-06 [1.0015764] [-0.00358341]
# 1400 1.6730027e-06 [1.0015023] [-0.00341503]
# 1420 1.5194441e-06 [1.0014318] [-0.00325458]
# 1440 1.3801897e-06 [1.0013644] [-0.00310167]
# 1460 1.2536236e-06 [1.0013005] [-0.00295597]
# 1480 1.1386356e-06 [1.0012394] [-0.00281712]
# 1500 1.0341988e-06 [1.0011812] [-0.00268483]
# 1520 9.3922876e-07 [1.0011257] [-0.00255875]
# 1540 8.530123e-07 [1.0010728] [-0.00243857]
# 1560 7.7495207e-07 [1.0010225] [-0.00232409]
# 1580 7.038794e-07 [1.0009745] [-0.00221502]
# 1600 6.3930764e-07 [1.0009288] [-0.00211103]
# 1620 5.8066513e-07 [1.0008852] [-0.00201191]
# 1640 5.2750966e-07 [1.0008438] [-0.00191745]
# 1660 4.791336e-07 [1.0008041] [-0.00182743]
# 1680 4.3510758e-07 [1.0007662] [-0.00174166]
# 1700 3.9533165e-07 [1.0007304] [-0.00165999]
# 1720 3.5914027e-07 [1.0006963] [-0.00158209]
# 1740 3.2626568e-07 [1.0006634] [-0.00150786]
# 1760 2.9637457e-07 [1.0006324] [-0.0014372]
# 1780 2.6925034e-07 [1.0006028] [-0.00136975]
# 1800 2.4454678e-07 [1.0005742] [-0.00130555]
# 1820 2.2213398e-07 [1.0005478] [-0.00124434]
# 1840 2.0181089e-07 [1.0005217] [-0.00118601]
# 1860 1.8336738e-07 [1.0004976] [-0.0011304]
# 1880 1.6648825e-07 [1.0004739] [-0.00107739]
# 1900 1.5130405e-07 [1.000452] [-0.00102687]
# 1920 1.3747034e-07 [1.0004306] [-0.00097881]
# 1940 1.2482418e-07 [1.0004106] [-0.00093282]
# 1960 1.1345162e-07 [1.0003915] [-0.00088924]
# 1980 1.03001376e-07 [1.0003728] [-0.00084749]
# 2000 9.360468e-08 [1.0003556] [-0.00080778]
